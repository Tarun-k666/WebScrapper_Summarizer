# %%
from openai import OpenAI

def call_model(system_text,user_text):
    MODEL='llama3.2'
    openai=OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")
    response = openai.chat.completions.create(
    model=MODEL,
    messages=[{"role":"system","content":system_text},{"role":"user","content":user_text}]
        )
    print(response.choices[0].message.content)

# %%
from scrapper import get_page_content
ed=get_page_content("https://www.ibm.com/think/topics/generative-ai")

# %%
system_prompt="""
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_pre=f"""Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
call_model(system_prompt,user_prompt_pre+ed)
# Out:
# **Short summary of the website**
# A vast, rambling guide to Machine Learning and AI from IBM, covering various types, algorithms, techniques, and applications.
#
# **Main points:**
#
# * Generative AI is not explicitly defined; instead, it's explored in a separate section.
# * Notable topics include Neural Networks (with subsections on Recurrent Neural Networks, Convolutional Neural Networks, Transformer Models), Transfer Learning, and Reinforcement Learning.
# * The website seems to be more focused on theoretical concepts than hands-on tutorials or practical applications.
