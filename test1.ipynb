# %%
from openai import OpenAI

def call_model(system_text,user_text):
    MODEL='llama3.2'
    openai=OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")
    response = openai.chat.completions.create(
    model=MODEL,
    messages=[{"role":"system","content":system_text},{"role":"user","content":user_text}]
        )
    print(response.choices[0].message.content)

# %%
from scrapper import get_page_content
url=input("Enter URL to summarize: ")
ed=get_page_content(url)

# %%
system_prompt="""
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_pre=f"""Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
call_model(system_prompt,user_prompt_pre+ed)
# Out:
# # IBM Machine Learning Overview
#
# Apparently, IBM is trying to educate us on machine learning without getting too technical.
#
# Machine learning is a type of "machine learning types" which sounds like a fancy way of saying it's a big deal. IBM covers various subfields, including supervised and unsupervised learning, feature engineering, dimensionality reduction, self-supervised learning, and even deep learning.
#
# The website touches upon generative AI briefly, comparing it to predictive AI, but doesn't dive deeper into the topic beyond announcing that "Generative model" is a part of the larger Generative AI section.
#
# That's about it for IBM's machine learning knowledge sharing party.
