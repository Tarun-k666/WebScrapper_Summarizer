# %%
from openai import OpenAI
from IPython.display import Markdown, display
from scrapper import get_page_content

# %%
system_prompt="""
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_pre=f"""Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
def message_for_LLM(data):
    messages=[{"role":"system","content":system_prompt},
              {"role":"user","content":user_prompt_pre+data}]
    return messages

# %%
def call_model(url):
    data=get_page_content(url)
    MODEL='llama3.2'
    openai=OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")
    response = openai.chat.completions.create(
    model=MODEL,
    messages=message_for_LLM(data)
        )
    return response.choices[0].message.content

# %%
def display_markdown(url):
    summary=call_model(url)
    display(Markdown(summary))

# %%
url=input("Enter URL to summarize: ")
display_markdown(url)
# Out:
# ### A Snarky Summation of Edward Donner's Website
#
# It appears Edward Donner is a wannabe DJ, amateur electronic music producer, and AI enthusiast. He co-founded Nebula.io, an AI startup that uses LLMs to help people discover their potential, much like how he wants to discover the meaning behind the things on Hacker News.
#
# ### Announcements and News
#
# - **2025 AI Executive Briefing**: Because who doesn't want a personalized briefing on AI?
# - **Be an AI Engineer and Leader: The Curriculum**: Sounds like a course that'll teach you the "art" of working with LLMs.
# - **AI in Production: Gen AI and Agentic AI on AWS at scale**: LLMs and AWS, because who needs human insight when you can rely on cloud computing?
# - **The Unique Energy of an AI Live Event** (on Nov 11, 2025): Sounds like a fun event where LLMs will probably outsmart each other... again.

# %%
system_prompt = """
You are a expert trader and have extensive knowledge of financial markets.With years of experience in trading stocks, 
forex, and cryptocurrencies, you provide insightful analysis and strategies to help users make informed investment decisions. 
You have provided accurate market predictions and trading advice in the past.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown."
"""
user_prompt = """
Provide a detailed analysis of the current financial market trends, including key indicators and potential investment opportunities.
"""

# Step 2: Make the messages list

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}

]

MODEL='llama3.2'
openai=OpenAI(base_url="http://localhost:11434/v1", api_key="ollama")
response = openai.chat.completions.create(
model=MODEL,
messages=messages
    )

display(Markdown(response.choices[0].message.content))
# Out:
# # Market Overview
# The global financial markets are experiencing significant changes due to the ongoing COVID-19 pandemic, rising inflation, and shifting economic policies. The impact of the pandemic is still being felt across various sectors, while inflation pressures are pushing interest rates upwards.
#
# ## Key Indicators:
#
# - **Inflation Rate**: The inflation rate has increased in many economies, including the United States and Europe, to levels not seen in several decades. Central banks are raising interest rates in an effort to curb this trend.
# - **Treasury Yields**: The trend of treasury yields increasing is a sign that central banks are becoming more hawkish. This could indicate a higher risk environment for investors.
# - **Cryptocurrency Prices**: Cryptocurrencies have experienced volatility, with some experiencing significant price corrections while others have seen growth.
#
# ## Sectors to Watch:
#
# ### 1. Renewable Energy
#
# ...
